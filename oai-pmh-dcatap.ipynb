# %%
import requests
import xml.etree.ElementTree as ET
import rdflib

rdf_ns = "http://www.w3.org/1999/02/22-rdf-syntax-ns#"

response = requests.get('https://portal.odissei.nl/oai?verb=GetRecord&identifier=doi:10.17026/DANS-222-GVUS&metadataPrefix=dcat3-rdfxml')

root = ET.fromstring(response.text)
rdf_element = root.find(f".//{{{rdf_ns}}}RDF")

# print(ET.tostring(rdf_element, encoding='unicode', method='xml'))
rdf_graph = rdflib.Graph()
rdf_graph.parse(data=ET.tostring(rdf_element, encoding='unicode', method='xml'), format='xml')
print(rdf_graph.serialize(format='turtle'))
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns3: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://portal.odissei.nl/> a dcat:Catalog ;
#     dcterms:creator <https://ror.org/03m8v6t10> ;
#     dcterms:description "The ODISSEI Portal combines metadata from a wide variety of social sciences research data repositories into a single interface, allowing for advanced semantic queries to support findability, and facilitate data access."@en ;
#     dcterms:publisher <https://ror.org/03m8v6t10> ;
#     dcterms:title "ODISSEI Portal"@en ;
#     dcat:contactPoint <https://odissei-data.nl/#contact> ;
#     dcat:dataset <https://doi.org/10.17026/DANS-222-GVUS> .
#
# <https://doi.org/10.17026/DANS-222-GVUS> a dcat:Dataset ;
#     dcterms:creator [ a foaf:Agent ;
#             foaf:name "Stichting Zuidenwind Filmprodukties (copyright)" ],
# ...

# %%
# %%bash
# pip install rdflib
# Out:
# ...
#   Using cached rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Using cached rdflib-7.6.0-py3-none-any.whl (615 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [rdflib]━━━━━━━━━━━ 2/2 [rdflib]
# ...

# %%
xml = '''<OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd"><responseDate>2026-07-30T12:30:04Z</responseDate><request verb="GetRecord" identifier="doi:10.17026/DANS-222-GVUS" metadataPrefix="dcat3-rdfxml">https://portal.odissei.nl/oai</request><GetRecord><record><header><identifier>doi:10.17026/DANS-222-GVUS</identifier><datestamp>2025-10-14T13:43:29Z</datestamp><setSpec>DANS</setSpec></header><metadata>
<rdf:RDF
    xmlns:spdx="http://spdx.org/rdf/terms#"
    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
    xmlns:dcatap="http://data.europa.eu/r5r/"
    xmlns:locn="http://www.w3.org/ns/locn#"
    xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
    xmlns:dct="http://purl.org/dc/terms/"
    xmlns:owl="http://www.w3.org/2002/07/owl#"
    xmlns:eli="http://data.europa.eu/eli/ontology#"
    xmlns:vcard="http://www.w3.org/2006/vcard/ns#"
    xmlns:skos="http://www.w3.org/2004/02/skos/core#"
    xmlns:geo="http://www.opengis.net/ont/geosparql#"
    xmlns:dcat="http://www.w3.org/ns/dcat#"
    xmlns:foaf="http://xmlns.com/foaf/0.1/"
    xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
  <dcat:Catalog rdf:about="https://portal.odissei.nl/">
    <dcat:dataset>
      <dcat:Dataset rdf:about="https://doi.org/10.17026/DANS-222-GVUS">
        <dcat:keyword>SS</dcat:keyword>
        <dct:issued rdf:datatype="http://www.w3.org/2001/XMLSchema#date"
        >2009-11-05</dct:issued>
        <dcat:keyword>Tweede Wereldoorlog</dcat:keyword>
        <dcat:contactPoint>
          <vcard:Kind rdf:about="https://odissei-data.nl/#contact">
            <vcard:fn xml:lang="en">Open Data Infrastructure for Social Science and Economic Innovations</vcard:fn>
            <dct:identifier>https://ror.org/03m8v6t10</dct:identifier>
            <vcard:organization-name>ODISSEI</vcard:organization-name>
            <vcard:hasURL rdf:resource="https://odissei-data.nl/"/>
          </vcard:Kind>
        </dcat:contactPoint>
        <dct:license rdf:resource="https://doi.org/10.17026/fp39-0x58"/>
        <dct:title>Getuigen Verhalen, Nederlandse SS'ers, interview 04</dct:title>
        <dct:hasVersion>V1.0</dct:hasVersion>
        <dct:creator>
          <foaf:Agent>
            <foaf:name>Seelen,  J.</foaf:name>
          </foaf:Agent>
        </dct:creator>
        <dcat:theme rdf:resource="http://publications.europa.eu/resource/authority/data-theme/SOCI"/>
        <dct:description>&lt;p&gt;De geïnterviewde meldde zich als 16-jarige in 1941 aan voor de Waffen-SS. Werd na zijn opleiding in Duitsland ingedeeld bij de Divisie 'Winkin'. In 1943 overgeplaatst naar de Divisie 'Nordland'. Vervolgens Kroatië, Leningrad, Narva en Kurland, waar hij ernstig gewond raakte. Tijdens zijn revalidatie werd hij in een hospitaal door het Rode Leger gevangengenomen. Is in 1946 teruggekeerd naar Duitsland, waar hij besloot een nieuw leven op te bouwen.&lt;br&gt;De interviews zijn voorlopig niet beschikbaar.&lt;/p&gt;</dct:description>
        <dcat:landingPage rdf:resource="https://portal.odissei.nl/dataset.xhtml?persistentId=doi:10.17026/DANS-222-GVUS"/>
        <dct:identifier>doi:10.17026/DANS-222-GVUS</dct:identifier>
        <dct:publisher>
          <foaf:Agent rdf:about="https://ror.org/03m8v6t10">
            <foaf:name>ODISSEI Portal</foaf:name>
          </foaf:Agent>
        </dct:publisher>
        <dcat:keyword>oral history</dcat:keyword>
        <dct:creator>
          <foaf:Agent>
            <foaf:name>Stichting Zuidenwind Filmprodukties (copyright)</foaf:name>
          </foaf:Agent>
        </dct:creator>
        <dct:modified rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime"
        >2025-10-07T01:01:10Z</dct:modified>
      </dcat:Dataset>
    </dcat:dataset>
    <dcat:contactPoint rdf:resource="https://odissei-data.nl/#contact"/>
    <dct:creator rdf:resource="https://ror.org/03m8v6t10"/>
    <dct:description xml:lang="en">The ODISSEI Portal combines metadata from a wide variety of social sciences research data repositories into a single interface, allowing for advanced semantic queries to support findability, and facilitate data access.</dct:description>
    <dct:publisher rdf:resource="https://ror.org/03m8v6t10"/>
    <dct:title xml:lang="en">ODISSEI Portal</dct:title>
  </dcat:Catalog>
</rdf:RDF>
</metadata></record></GetRecord></OAI-PMH>'''
